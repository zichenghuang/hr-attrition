# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style as style
# %matplotlib inline
import seaborn as sns

sns.set_style('darkgrid')

# %%
data = pd.read_csv('Data/WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
data = data.drop(columns=['StandardHours', 
                          'EmployeeCount', 
                          'Over18',
                          'EmployeeNumber'
                        ])

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# std                   1.093082    20.329428        0.711561     1.106940
# min                   1.000000    30.000000        1.000000     1.000000
# ...

# %%
# data.BusinessTravel.replace(to_replace = {'Non-Travel': 1, 'Travel_Rarely': 2, 'Travel_Frequently': 3}, inplace = True)
# data.Department.replace(to_replace = {'Sales': 1, 'Research & Development': 2, 'Human Resources': 3}, inplace = True)
# data.EducationField.replace(to_replace = {'Life Sciences': 1, 'Medical': 2, 'Marketing': 3, 'Technical Degree': 4, 'Human Resources': 5, 'Other':6}, inplace = True)
data.MaritalStatus.replace(to_replace = {'Single': 1, 'Married': 2, 'Divorced': 3}, inplace = True)

# %% [markdown]
# #### How is attrition dependent on Ages

# %%
fig, ax = plt.subplots(2, 1, figsize=(14, 10), sharex=False)
sns.histplot(ax=ax[0], 
             data=data, 
             x='Age', 
             hue='Attrition', 
             bins='auto',
             multiple='fill', 
#              stat='count', 
             palette='muted', 
             legend=True)
sns.boxplot(ax=ax[1], 
            data=data, 
            x='Age', 
            y='Attrition', 
            palette='muted')
ax[0].set_ylabel('Probability')
ax[0].set_title('Stacked bar plot: Age by Attrition')
ax[1].set_ylabel(None)
ax[1].set_title('Boxplot: Age by Attrition');
plt.savefig('city_development_index.png')

# %%
# fig, ax = plt.subplots(1, 1, figsize=(8, 6))
# ax = sns.histplot(data = data,
#             x = "Age",
#             hue = "Attrition",
#             palette = "muted")

# ax.set_title("Age of Employees by Attrition Status")
# ax.set_ylabel(None)
# ax.set_xlabel("Age");

# %% [markdown]
# #### How is attrition dependent on Monthly income

# %%
fig, ax = plt.subplots(2, 1, figsize=(14, 10), sharex=False)
sns.histplot(ax=ax[0], 
             data=data, 
             x='MonthlyIncome', 
             hue='Attrition', 
             bins='auto',
             multiple='fill', 
#              stat='count', 
             palette='muted', 
             legend=True)
sns.boxplot(ax=ax[1], 
            data=data, 
            x='MonthlyIncome', 
            y='Attrition', 
            palette='muted')
ax[0].set_ylabel('Probability')
ax[0].set_title('Stacked bar plot: Monthly Income by Attrition')
ax[1].set_ylabel(None)
ax[1].set_title('Boxplot: Monthly Income by Attrition');
plt.savefig('city_development_index.png')

# %% [markdown]
# #### How is attrition dependent on distance from home

# %%
fig, ax = plt.subplots(2, 1, figsize=(14, 10), sharex=False)
sns.histplot(ax=ax[0], 
             data=data, 
             x='DistanceFromHome', 
             hue='Attrition', 
             bins='auto',
             multiple='fill', 
#              stat='count', 
             palette='muted', 
             legend=True)
sns.boxplot(ax=ax[1], 
            data=data, 
            x='DistanceFromHome', 
            y='Attrition', 
            palette='muted')
ax[0].set_ylabel('Probability')
ax[0].set_title('Stacked bar plot: Distance From Home by Attrition')
ax[1].set_ylabel(None)
ax[1].set_title('Boxplot: Distance From Home by Attrition');
plt.savefig('city_development_index.png')

# %% [markdown]
# #### How is attrition dependent on Work Life Balance

# %%
fig, ax = plt.subplots(2, 1, figsize=(14, 10), sharex=False)
sns.histplot(ax=ax[0], 
             data=data, 
             x='WorkLifeBalance', 
             hue='Attrition', 
             bins='auto',
             multiple='fill', 
#              stat='count', 
             palette='muted', 
             legend=True)
sns.boxplot(ax=ax[1], 
            data=data, 
            x='WorkLifeBalance', 
            y='Attrition', 
            palette='muted')
ax[0].set_ylabel('Probability')
ax[0].set_title('Stacked bar plot: Work Life Balance by Attrition')
ax[1].set_ylabel(None)
ax[1].set_title('Boxplot: Work Life Balance by Attrition');
plt.savefig('city_development_index.png')

# %% [markdown]
# #### How is attrition dependent on Marital Status

# %%
fig, ax = plt.subplots(2, 1, figsize=(14, 10), sharex=False)
sns.histplot(ax=ax[0], 
             data=data, 
             x='MaritalStatus', 
             hue='Attrition', 
             bins='auto',
             multiple='fill', 
#              stat='count', 
             palette='muted', 
             legend=True)
sns.boxplot(ax=ax[1], 
            data=data, 
            x='MaritalStatus', 
            y='Attrition', 
            palette='muted')
ax[0].set_ylabel('Probability')
ax[0].set_title('Stacked bar plot: Marital Status by Attrition')
ax[1].set_ylabel(None)
ax[1].set_title('Boxplot: Marital Status by Attrition');
plt.savefig('city_development_index.png')

# %% [markdown]
# #### How is attrition dependent on Job Statisfaction

# %%
fig, ax = plt.subplots(2, 1, figsize=(14, 10), sharex=False)
sns.histplot(ax=ax[0], 
             data=data, 
             x='JobSatisfaction', 
             hue='Attrition', 
             bins='auto',
             multiple='fill', 
#              stat='count', 
             palette='muted', 
             legend=True)
sns.boxplot(ax=ax[1], 
            data=data, 
            x='JobSatisfaction', 
            y='Attrition', 
            palette='muted')
ax[0].set_ylabel('Probability')
ax[0].set_title('Stacked bar plot: Job Satisfaction by Attrition')
ax[1].set_ylabel(None)
ax[1].set_title('Boxplot: Job Satisfaction by Attrition');
plt.savefig('city_development_index.png')

# %% [markdown]
# #### How is attrition dependent on Year since Gender

# %%
data.Gender.replace(to_replace = {'Female': 1, 'Male': 0}, inplace = True)

# %%
fig, ax = plt.subplots(2, 1, figsize=(14, 10), sharex=False)
sns.histplot(ax=ax[0], 
             data=data, 
             x='Gender', 
             hue='Attrition', 
             bins='auto',
             multiple='fill', 
#              stat='count', 
             palette='muted', 
             legend=True)
sns.boxplot(ax=ax[1], 
            data=data, 
            x='Gender', 
            y='Attrition', 
            palette='muted')
ax[0].set_ylabel('Probability')
ax[0].set_title('Stacked bar plot: Gender by Attrition')
ax[1].set_ylabel(None)
ax[1].set_title('Boxplot: Gender by Attrition');
plt.savefig('city_development_index.png')

# %% [markdown]
# #### Covert categorical variables to numerical variables

# %%
data = data.drop(columns=['JobRole'])
data.Attrition.replace(to_replace = dict(Yes = 1, No = 0), inplace = True)
data.BusinessTravel.replace(to_replace = {'Non-Travel': 1, 'Travel_Rarely': 2, 'Travel_Frequently': 3}, inplace = True)
data.Department.replace(to_replace = {'Sales': 1, 'Research & Development': 2, 'Human Resources': 3}, inplace = True)
data.EducationField.replace(to_replace = {'Life Sciences': 1, 'Medical': 2, 'Marketing': 3, 'Technical Degree': 4, 'Human Resources': 5, 'Other':6}, inplace = True)

# %%
data.OverTime.replace(to_replace = dict(Yes = 1, No = 0), inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   int64
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int64
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   int64
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   int64
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobSatisfaction           1470 non-null   int64
# ...

# %%
correlation_age = data['Attrition'].corr(data['Age'])
correlation_age = np.round(correlation_age,3)
correlation_age
# Out:
# -0.159

# %%
correlation_income = data['Attrition'].corr(data['MonthlyIncome'])
correlation_income = np.round(correlation_income,3)
correlation_income
# Out:
# -0.16

# %%
correlation_distance = data['Attrition'].corr(data['DistanceFromHome'])
correlation_distance = np.round(correlation_distance,3)
correlation_distance
# Out:
# 0.078

# %% [markdown]
# #### heat map

# %%
# drop categorical variables
data = data.drop(columns=['BusinessTravel', 
                          'Department', 
                          'EducationField',
                          'Gender',
                          'MaritalStatus',
                          'OverTime',
                          'MonthlyRate'
                        ])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   DailyRate                 1470 non-null   int64
#  3   DistanceFromHome          1470 non-null   int64
#  4   Education                 1470 non-null   int64
#  5   EnvironmentSatisfaction   1470 non-null   int64
#  6   HourlyRate                1470 non-null   int64
#  7   JobInvolvement            1470 non-null   int64
#  8   JobLevel                  1470 non-null   int64
#  9   JobSatisfaction           1470 non-null   int64
#  10  MonthlyIncome             1470 non-null   int64
#  11  MonthlyRate               1470 non-null   int64
#  12  NumCompaniesWorked        1470 non-null   int64
#  13  PercentSalaryHike         1470 non-null   int64
# ...

# %%
corr_matrix = data.corr()

# %%
f, ax = plt.subplots(figsize=(20, 16))
sns.heatmap(corr_matrix, cmap='viridis');

# %%
corr_matrix.round(3)
# Out:
#                             Age  Attrition  DailyRate  DistanceFromHome  \
# Age                       1.000     -0.159      0.011            -0.002
# Attrition                -0.159      1.000     -0.057             0.078
# DailyRate                 0.011     -0.057      1.000            -0.005
# DistanceFromHome         -0.002      0.078     -0.005             1.000
# Education                 0.208     -0.031     -0.017             0.021
# EnvironmentSatisfaction   0.010     -0.103      0.018            -0.016
# HourlyRate                0.024     -0.007      0.023             0.031
# JobInvolvement            0.030     -0.130      0.046             0.009
# JobLevel                  0.510     -0.169      0.003             0.005
# JobSatisfaction          -0.005     -0.103      0.031            -0.004
# MonthlyIncome             0.498     -0.160      0.008            -0.017
# NumCompaniesWorked        0.300      0.043      0.038            -0.029
# ...

# %%
corr_matrix[corr_matrix['Attrition'].index != 'Attrition'].Attrition
# Out:
# Age                        -0.159205
# DailyRate                  -0.056652
# DistanceFromHome            0.077924
# Education                  -0.031373
# EnvironmentSatisfaction    -0.103369
# HourlyRate                 -0.006846
# JobInvolvement             -0.130016
# JobLevel                   -0.169105
# JobSatisfaction            -0.103481
# MonthlyIncome              -0.159840
# NumCompaniesWorked          0.043494
# PercentSalaryHike          -0.013478
# PerformanceRating           0.002889
# RelationshipSatisfaction   -0.045872
# StockOptionLevel           -0.137145
# TotalWorkingYears          -0.171063
# TrainingTimesLastYear      -0.059478
# WorkLifeBalance            -0.063939
# YearsAtCompany             -0.134392
# YearsInCurrentRole         -0.160545
# YearsSinceLastPromotion    -0.033019
# YearsWithCurrManager       -0.156199
# Name: Attrition, dtype: float64

# %%
corr_matrix.index[corr_matrix['Attrition'].index != 'Attrition']
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'MonthlyIncome', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
ax.stem(corr_matrix.index[corr_matrix['Attrition'].index != 'Attrition'],
        corr_matrix[corr_matrix['Attrition'].index != 'Attrition'].Attrition)
ax.set_ylabel('Correlation')
ax.set_title('Correlation of features and target label')
plt.xticks(rotation=90);
